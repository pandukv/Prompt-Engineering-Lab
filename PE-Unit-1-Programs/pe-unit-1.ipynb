# %%
import os
from openai import OpenAI

client = OpenAI(
    api_key=os.environ["GROQ_API_KEY"],
    base_url="https://api.groq.com/openai/v1"
)

response = client.chat.completions.create(
    model="llama-3.3-70b-versatile",
    messages=[
        {"role": "user", "content": "Say Hello, world!"}
    ]
)

print(response.choices[0].message.content)
# Out:
# Hello, world!

# %%
import os
from openai import OpenAI

# Initialize the client using the Groq API base URL and environment variable
client = OpenAI(
    base_url="https://api.groq.com/openai/v1",
    api_key=os.environ.get("GROQ_API_KEY")
)

# Execute the naïve prompt as defined in the experimental procedure
response = client.chat.completions.create(
    model="llama-3.3-70b-versatile",
    messages=[
        {
            "role": "user", 
            "content": "Write a one-paragraph bio of Ada Lovelace."
        }
    ]
)

# Print the output for lab observation
print("--- Naïve Prompt Output ---")
print(response.choices[0].message.content)
#print(response.output_text)
# Out:
# --- Naïve Prompt Output ---
# Ada Lovelace, born Augusta Ada Byron on December 10, 1815, was a British mathematician and writer, often regarded as the world's first computer programmer. As the daughter of the famous poet Lord George Gordon Byron, Ada was raised by her mother, Anne Isabella Milbanke, who encouraged her interest in mathematics and science. Ada's work on Charles Babbage's proposed mechanical general-purpose computer, the Analytical Engine, led to her writing a series of notes that included what is considered to be the first computer program, making her a pioneer in the field of computer science. Her notes on the Analytical Engine, which were published in 1843, showcased her understanding of the machine's capabilities and her vision for its potential to go beyond mere calculation and perform any task that could be expressed in a series of steps. Through her groundbreaking work, Ada Lovelace left a lasting legacy in the fields of mathematics, computer science, and women's contributions to technology.

# %%
import os
from openai import OpenAI

# Initialize the client using the Groq API base URL and environment variable
client = OpenAI(
    base_url="https://api.groq.com/openai/v1",
    api_key=os.environ.get("GROQ_API_KEY")
)

# The enhanced prompt string combines the three required structural elements
enhanced_prompt = (
    "You are an expert historian. [Role Framing] "
    "Provide a detailed bio of Ada Lovelace, focusing on her work with "
    "Charles Babbage and the Analytical Engine. [Specificity] "
    "Write this in exactly one academic paragraph. [Format Instructions]"
)

response = client.chat.completions.create(
    model="llama-3.3-70b-versatile",
    messages=[
        {"role": "user", "content": enhanced_prompt}
    ]
)

print("--- Enhanced Output ---")
print(response.choices[0].message.content)
# Out:
# --- Enhanced Output ---
# Ada Lovelace, born Augusta Ada Byron on December 10, 1815, was a pioneering mathematician and computer scientist who is widely regarded as the first computer programmer due to her groundbreaking work on Charles Babbage's proposed mechanical general-purpose computer, the Analytical Engine. As the daughter of the famous poet Lord George Gordon Byron, Ada was encouraged from a young age to pursue her interest in mathematics, which led to her acquaintance with Babbage and his innovative machine. Between 1842 and 1843, Lovelace translated an article on the Analytical Engine by Italian mathematician Luigi Menabrea, adding her own notes and comments that ended up being longer than the original article, and it was in these notes that she expressed her vision for the engine's potential to go beyond mere calculation and perform any task that could be expressed in a series of steps, essentially predicting the capabilities of modern computers. Furthermore, Lovelace is credited with devising a method for calculating a sequence of Bernoulli numbers using the Analytical Engine, which is considered to be the first computer program, demonstrating her profound understanding of the machine's capabilities and limitations. Through her collaboration with Babbage and her work on the Analytical Engine, Lovelace not only made significant contributions to the development of computer science but also left an indelible mark on the history of mathematics and technology, cementing her place as a trailblazer in the field of computer programming and a testament to the power of human ingenuity and creativity.

# %%
import os
from openai import OpenAI

# Setup: Ensure your API key is configured as done in Lab 1
# os.environ["OPENAI_API_KEY"] = "your-api-key-here"
#client = OpenAI(api_key=os.environ.get("OPENAI_API_KEY"))

# Initialize the client using the Groq API base URL and environment variable
client = OpenAI(
    base_url="https://api.groq.com/openai/v1",
    api_key=os.environ.get("GROQ_API_KEY")
)

def get_response(prompt):
    """Helper function to send the prompt to the model and return the response."""
    response = client.chat.completions.create(
        model="llama-3.3-70b-versatile", # You can also use gpt-4
        messages=[{"role": "user", "content": prompt}]
    )
    return response.choices[0].message.content

print("--- Lab 3: Iterative Refinement on a Simple Task ---\n")
# Round A: Minimal instruction
prompt_a = "Summarize the plot of the Shakespearean play Romeo and Juliet."
print("Iteration A (Minimal Instruction):")
print(f"Prompt: {prompt_a}")
print(f"Output:\n{get_response(prompt_a)}")
print("-" * 40)

# Round B: Addition of length and style constraints
prompt_b = "Summarize the plot of the Shakespearean play Romeo and Juliet in exactly two sentences. Write it in the style of a dramatic movie trailer."
print("Iteration B (Length & Style Constraints):")
print(f"Prompt: {prompt_b}")
print(f"Output:\n{get_response(prompt_b)}")
print("-" * 40)

# Round C: Specification of key content elements (setting and theme)
prompt_c = """
Summarize the plot of the Shakespearean play Romeo and Juliet in exactly two sentences. 
Write it in the style of a dramatic movie trailer. 
Make sure to explicitly mention the setting of Verona and the core theme of fatal family rivalry.
"""
print("Iteration C (Setting & Theme Specified):")
print(f"Prompt: {prompt_c}")
print(f"Output:\n{get_response(prompt_c)}")
print("\n")
# Out:
# --- Lab 3: Iterative Refinement on a Simple Task ---
#
# Iteration A (Minimal Instruction):
# Prompt: Summarize the plot of the Shakespearean play Romeo and Juliet.
# Output:
# The tragic play "Romeo and Juliet" by William Shakespeare revolves around the intense and ill-fated romance between two young lovers from feuding families in Verona. The conflict begins with a brawl between the Montagues and the Capulets, which is eventually broken up by the Prince of Verona, who warns both families to put an end to their rivalry.
#
# Against this backdrop of hatred and violence, Romeo, a Montague, falls deeply in love with Juliet, the beautiful daughter of the Capulets, at a ball hosted by her family. They exchange vows of love, but their families' animosity towards each other makes their love impossible.
#
# The two decide to marry in secret, with the help of Friar Lawrence, a wise and understanding priest. However, their happiness is short-lived, as Romeo's hot-headed friend Mercutio is killed in a duel with Juliet's cousin Tybalt. In a rage, Romeo kills Tybalt and is banished from Verona.
#
# Juliet's parents, unaware of her secret marriage, arrange for her to marry another man, but she refuses. In desperation, Juliet turns to Friar Lawrence, who gives her a potion to make her appear dead. The plan is for her to be buried, and then Romeo will rescue her and they can escape together.
#
# However, the plan goes awry. Romeo believes Juliet is really dead and poisons himself in her tomb. Juliet awakens to find Romeo dead and, in grief and despair, stabs herself with his dagger to join him in death. The tragic end of the two lovers ultimately brings peace between their families, as they realize the senselessness of their long-standing feud.
#
# Through the tragic tale of Romeo and Juliet, Shakespeare explores themes of love, fate, and the devastating consequences of blind hatred and revenge. The play remains one of the most iconic and enduring love stories in literature, continuing to captivate audiences with its poignant and timeless portrayal of star-crossed lovers.
# ----------------------------------------
# Iteration B (Length & Style Constraints):
# Prompt: Summarize the plot of the Shakespearean play Romeo and Juliet in exactly two sentences. Write it in the style of a dramatic movie trailer.
# Output:
# In a world torn apart by hatred and fate, two star-crossed lovers, Romeo and Juliet, dare to defy the odds and risk everything for a love that will change the course of their lives forever. From the sun-kissed streets of Verona to the darkest depths of tragedy, this epic tale of passion and woe will take you on a heart-wrenching journey of love, loss, and the ultimate sacrifice, as the Montagues and Capulets clash in a battle that will leave only heartbreak in its wake.
# ----------------------------------------
# Iteration C (Setting & Theme Specified):
# Prompt:
# Summarize the plot of the Shakespearean play Romeo and Juliet in exactly two sentences.
# Write it in the style of a dramatic movie trailer.
# Make sure to explicitly mention the setting of Verona and the core theme of fatal family rivalry.
#
# Output:
# In the sweltering city of Verona, a legendary tale of star-crossed lovers unfolds as Romeo and Juliet, two young souls from feuding families, dare to defy the deadly legacy of hatred that has haunted their streets for generations, their love igniting a flame that threatens to consume them all. Against the backdrop of a city torn apart by fatal family rivalry, the Montagues and Capulets' bitter vendetta sets the stage for a heart-wrenching tragedy that will leave only devastation in its wake, as the fate of the two lovers hangs precariously in the balance, poised to become the ultimate sacrifice to the senseless feud that has destroyed their world.

# %%
import os
from openai import OpenAI

# Setup: Ensure your API key is configured as done in Lab 1
# os.environ["OPENAI_API_KEY"] = "your-api-key-here"
# Initialize the client using the Groq API base URL and environment variable
client = OpenAI(
    base_url="https://api.groq.com/openai/v1",
    api_key=os.environ.get("GROQ_API_KEY")
)

def get_response(prompt):
    """Helper function to send the prompt to the model and return the response."""
    response = client.chat.completions.create(
        model="llama-3.3-70b-versatile", # You can also use gpt-4
        messages=[{"role": "user", "content": prompt}]
    )
    return response.choices[0].message.content

print("--- Lab 4: Diagnosing Prompt Failures & Edge Cases ---\n")

# Step 1: Craft a vague prompt 
vague_prompt = "Give me some good things to eat."
print("Step 1: Vague Prompt")
print(f"Prompt: {vague_prompt}")
print(f"Output (Failure Mode: Ambiguity/Missing Context):\n{get_response(vague_prompt)}")
print("-" * 40)

# Step 2: Refine the prompt by adding examples and clarifying instructions
refined_prompt = """
I am looking for a high-protein, vegetarian dinner recipe that takes less than 30 minutes to make. 
Please provide the response in the exact following format:
Recipe Name:
Prep Time:
Ingredients List:
Instructions:

Example:
Recipe Name: Quick Tofu Stir-Fry
Prep Time: 15 minutes
Ingredients List: Tofu, broccoli, soy sauce, garlic...
Instructions: 1. Press tofu... 2. Chop vegetables... 3. Stir-fry...
"""
print("Step 2: Refined Prompt")
print(f"Prompt: {refined_prompt}")
print(f"Output (Fixed with clarification and examples):\n{get_response(refined_prompt)}")
print("\n")
# Out:
# --- Lab 4: Diagnosing Prompt Failures & Edge Cases ---
#
# Step 1: Vague Prompt
# Prompt: Give me some good things to eat.
# Output (Failure Mode: Ambiguity/Missing Context):
# Here are some delicious and popular food options:
#
# **Breakfast Ideas**
#
# 1. Avocado toast with scrambled eggs and cherry tomatoes
# 2. Greek yogurt with berries and granola
# 3. Overnight oats with banana and honey
# 4. Breakfast burrito with sausage, eggs, and cheese
# 5. Smoothie bowl with spinach, banana, and almond milk
#
# **Lunch Options**
#
# 1. Grilled chicken salad with mixed greens, cherry tomatoes, and balsamic vinaigrette
# 2. Turkey and avocado wrap with mixed greens and hummus
# 3. Quinoa bowl with roasted vegetables and a citrus vinaigrette
# 4. Soup and sandwich combo (e.g., tomato soup with a grilled cheese sandwich)
# 5. Sushi rolls with salmon, cucumber, and avocado
#
# **Dinner Ideas**
#
# 1. Grilled steak with roasted Brussels sprouts and sweet potato
# 2. Chicken fajitas with sautéed onions and bell peppers
# 3. Baked salmon with quinoa and steamed asparagus
# 4. Vegetable stir-fry with tofu and brown rice
# 5. Homemade pizza with tomato sauce, mozzarella, and fresh basil
#
# **Snacks**
#
# 1. Fresh fruit (e.g., apples, bananas, oranges)
# 2. Trail mix with nuts and dried fruits
# 3. Energy balls made with oats, nuts, and dried fruits
# 4. Yogurt parfait with granola and honey
# 5. Dark chocolate squares with almonds and sea salt
#
# **Desserts**
#
# 1. Chocolate chip cookies with a scoop of vanilla ice cream
# 2. Fresh berries with whipped cream and shortbread cookies
# 3. Cheesecake with a mixed berry compote
# 4. Brownies with a scoop of chocolate ice cream
# 5. Cinnamon sugar donuts with a caramel dipping sauce
#
# I hope these ideas inspire you to try something new and delicious!
# ----------------------------------------
# Step 2: Refined Prompt
# Prompt:
# I am looking for a high-protein, vegetarian dinner recipe that takes less than 30 minutes to make.
# Please provide the response in the exact following format:
# Recipe Name:
# Prep Time:
# Ingredients List:
# Instructions:
#
# Example:
# Recipe Name: Quick Tofu Stir-Fry
# Prep Time: 15 minutes
# Ingredients List: Tofu, broccoli, soy sauce, garlic...
# Instructions: 1. Press tofu... 2. Chop vegetables... 3. Stir-fry...
#
# Output (Fixed with clarification and examples):
# Recipe Name: Spinach and Lentil Curry
# Prep Time: 20 minutes
# Ingredients List: red or brown lentils, onion, garlic, ginger, frozen spinach, vegetable broth, coconut milk, curry powder, turmeric, salt, pepper, olive oil
# Instructions:
# 1. Rinse the lentils and cook them in vegetable broth according to package instructions.
# 2. In a pan, heat olive oil and sauté the onion, garlic, and ginger until the onion is translucent.
# 3. Add curry powder and turmeric to the pan and cook for 1 minute.
# 4. Stir in the cooked lentils, frozen spinach, and coconut milk.
# 5. Season with salt and pepper to taste, then serve hot over rice or with naan bread.
